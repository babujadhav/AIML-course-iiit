# %% [markdown]
# <a href="https://colab.research.google.com/github/babujadhav/AIMLtraining_jadhav/blob/main/visulasization_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)


x = np.random.random(100)
y = np.random.normal(size = 100)
print(x)
#distribution of data
plt.hist(x, bins = 20, color = 'red');
sns.histplot(y, bins=20, kde=True);
# Out:
# [0.45862828 0.71303249 0.11321565 0.43330996 0.07916213 0.52803428
#  0.02524315 0.75099961 0.6715066  0.53593864 0.8324645  0.42669425
#  0.23801681 0.72228587 0.97534835 0.98744424 0.47122731 0.14037641
#  0.40075536 0.76269727 0.49212372 0.04168643 0.76015824 0.82980108
#  0.07885078 0.80054389 0.71841386 0.42090851 0.84734061 0.91007004
#  0.81899142 0.97260388 0.43606855 0.23830821 0.48280333 0.1220685
#  0.33164883 0.06454748 0.99012139 0.06085695 0.96032851 0.46603747
#  0.7956441  0.81358904 0.13134624 0.88886214 0.99202633 0.80996435
#  0.71121971 0.61552333 0.55677408 0.35553855 0.33606806 0.17702307
#  0.82271835 0.35576785 0.55433664 0.86656733 0.36961703 0.69118275
#  0.26732043 0.70982898 0.33030678 0.50793    0.94369593 0.57596434
#  0.63987572 0.03600923 0.77681605 0.32244198 0.00399824 0.26670694
#  0.4695569  0.61292465 0.75516709 0.90548441 0.00193498 0.80363814
#  0.23501232 0.81360258 0.65451535 0.81395784 0.53637114 0.13027885
# ...

# %%
sns.kdeplot(x, color='red', fill=True)
sns.kdeplot(y, color='red', fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.kdeplot(x, color='red', fill=True)
sns.kdeplot(y, color='blue', fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.hisplot(x, color='red', fill=True)
sns.histplot(x, color='blue', fill=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-84fd5098f09a> in <cell line: 2>()
#       1 plt.subplot(1,2,1)
# ----> 2 sns.hisplot(x, color='red', fill=True)
#       3 sns.histplot(x, color='blue', fill=True)
#
# AttributeError: module 'seaborn' has no attribute 'hisplot'

# %%
tips_df = sns.load_dataset('tips')

# %%
print(tips_df.sample(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 127       14.52  2.00  Female     No  Thur   Lunch     2
# 91        22.49  3.50    Male     No   Fri  Dinner     2
# 110       14.00  3.00    Male     No   Sat  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2

# %%
tips_df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.histplot(tips_df.total_bill, color='blue', bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips_df.tip, color='blue', bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_df.tip/tips_df.total_bill, color='blue', bins=20)
# Out:
# <Axes: ylabel='Count'>

# %%
tips_df[tips_df.tip/tips_df.total_bill>0.4]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
days = tips_df.day.unique()
day_data={}
for each_day in days
  day_data[each_day] = [tips_df[tips_df['day']==]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-84e2e6207876> in <cell line: 1>()
# ----> 1 tips_df.tips_df.count()
#       2 days = tips_df.day.unique()
#       3 day_data={}
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tips_df'

# %%
tips_series = tips_df.groupby('day')['day'].count()

# %%
sns.barplot(x=tips_series.index, y=tips_series.values)
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# Relational plots

# %%
sns.relplot(data=tips_df, x='total_bill', y='tip')
sns.regplot(data=tips_df, x='total_bill', y='tip');

# %%
sns.lmplot(data=tips_df, x='total_bill', y='tip')

# %%
sns.lmplot(data=tips_df, x='total_bill', y='tip', hue='day', col='smoker', row='sex')

# %%
sns.pairplot(tips_df)

# %% [markdown]
# #composition of data

# %%
plt.pie(tips_series, labels=tips_series.index, autopct='%0.2f%%', shadow=True, explode=[0.1,0.0])
# Out:
# ([<matplotlib.patches.Wedge at 0x79645c1b6e00>,
# ...
#  [Text(-0.5226482572565508, 1.0802031286691824, 'Male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'Female')],
#  [Text(-0.30487815006632135, 0.6301184917236897, '64.34%'),
#   Text(0.2613241286282751, -0.5401015643345913, '35.66%')])
